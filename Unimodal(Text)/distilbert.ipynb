# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/meme-dataset/val_with_reason.csv
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9273.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9292.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4353.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6262.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2664.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9110.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1231.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1017.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7530.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8565.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6441.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5590.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2015.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2300.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3765.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1522.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9938.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6811.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7726.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6131.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1088.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7863.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8414.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9334.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1479.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8426.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9767.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9570.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7633.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1727.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9620.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2982.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8281.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1457.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4319.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2690.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7621.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9706.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8231.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1675.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6299.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2273.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3550.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1145.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9679.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5950.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6423.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3685.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7592.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7601.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9455.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1343.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9748.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3952.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2525.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3012.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9596.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2009.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3362.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4792.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4916.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9063.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6632.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5816.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9125.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5543.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1630.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8569.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5831.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6158.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4554.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8295.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4418.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6108.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5802.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3372.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3602.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5629.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7791.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5468.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2779.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2645.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3539.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7777.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5461.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3450.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7965.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1855.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1813.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9953.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7456.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4226.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6205.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8084.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6729.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1827.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9203.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2533.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7823.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7477.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8925.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9789.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5681.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6476.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3554.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1992.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9926.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5432.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4846.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1690.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5962.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1312.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3220.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4261.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8821.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8344.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2675.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3052.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6387.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6248.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4484.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3634.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6583.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8752.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9373.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2741.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4914.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8677.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7694.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2381.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6138.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8878.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2136.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4771.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4033.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9144.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7685.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3697.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1532.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1820.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8301.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6008.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5781.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1096.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4578.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2893.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9786.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1954.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2218.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6555.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9158.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9011.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3920.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6144.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6376.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9385.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9275.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1375.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9023.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2094.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5584.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4598.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9188.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2668.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5298.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4552.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5707.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3174.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2526.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1206.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5039.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7605.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9402.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4388.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3283.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2801.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1301.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6567.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3082.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4381.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8840.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4269.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2079.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8556.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4196.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3025.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4003.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5069.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1168.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3831.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8885.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9827.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4334.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6146.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3599.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5927.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5568.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9306.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4466.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7629.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5336.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2495.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1952.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7579.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9738.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3144.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3838.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1910.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1208.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4589.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5457.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9521.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1445.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5469.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9940.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1483.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6208.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7639.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1294.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1530.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3582.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1041.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7772.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9522.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1967.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5205.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3830.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5628.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9441.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1268.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7547.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9155.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1148.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9462.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6277.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9477.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8900.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9968.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4531.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1625.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8195.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8016.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9173.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5262.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5594.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9108.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9902.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3451.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6035.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1241.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9618.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7682.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8814.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9214.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6721.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2541.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2841.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4516.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7646.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8874.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5625.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4987.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5087.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2491.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2750.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8378.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9139.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9753.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9872.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4802.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8768.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6800.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8455.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9487.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9781.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9263.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6562.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5896.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8351.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4042.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1220.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5780.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9772.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2380.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8246.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6550.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3982.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6679.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3457.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8279.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2472.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9969.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9314.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8155.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8994.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2853.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7535.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1315.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1868.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1219.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1887.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9367.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2340.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9510.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3493.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8483.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9174.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7852.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1598.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6695.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8835.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3066.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5225.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1135.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4927.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9740.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4188.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6200.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4289.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9094.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1885.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4316.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9129.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6700.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5545.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8164.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8590.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8298.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4027.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1558.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1279.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1733.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9449.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8809.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6251.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4194.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3435.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2053.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6274.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2066.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5557.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6642.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5392.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8058.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4193.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8376.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8462.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6711.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5938.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6134.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9443.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3559.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7739.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6436.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5033.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5913.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6053.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3998.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2875.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3615.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8197.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5377.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3249.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9960.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9238.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9406.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6838.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8121.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5755.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7594.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6168.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8865.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3090.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4507.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9503.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2599.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9839.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7960.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9093.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5355.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4186.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6747.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9165.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2490.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1361.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8545.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1872.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7617.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3971.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9033.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8846.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6735.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6232.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5856.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9861.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3536.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8045.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6577.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1338.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5012.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9943.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2865.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9964.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7795.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4187.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5418.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6160.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7593.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1435.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1953.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5219.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4529.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9854.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1039.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6309.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6401.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2605.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6768.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9833.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4750.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6165.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2815.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7528.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9195.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8264.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2358.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2530.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5054.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6741.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5558.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2230.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8611.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1884.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2140.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6151.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4773.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2483.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6685.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3879.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6801.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6531.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6359.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5321.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3796.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9070.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7993.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9291.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2311.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7835.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7873.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9652.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9718.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2144.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4091.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8842.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9682.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3901.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4249.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9991.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2178.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5356.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9965.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4250.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6264.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8684.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2384.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6226.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8997.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2622.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9053.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5332.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8651.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5776.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7817.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1288.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4048.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1561.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7930.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8313.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3431.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4891.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3062.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5717.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3610.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3383.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3218.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/1121.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/7624.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5860.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3425.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6101.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/5510.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/6576.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2603.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/9648.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/3734.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/8367.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/4441.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_train_img/No Hate/2267.png
# ...
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5062.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3334.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/1506.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3594.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6457.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7036.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3273.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8908.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5680.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8812.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5903.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/1693.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/1689.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/2882.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5720.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7409.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9223.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5692.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6579.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3543.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8546.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9808.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9873.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4104.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9688.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8541.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8324.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/2423.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/2050.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/2608.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/2906.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8826.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3964.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/2971.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8289.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3996.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/1763.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9179.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6410.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7459.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4209.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9404.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/1725.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/1046.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6329.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5725.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5404.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7518.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/2295.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/2129.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4512.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/1342.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4506.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9322.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7109.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6283.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4698.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/1377.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4870.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3607.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6916.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3848.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7906.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4367.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6303.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/2749.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7350.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/2294.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6522.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3744.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8697.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9398.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6873.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7693.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8047.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5589.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4385.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8721.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5785.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7683.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8430.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7329.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/1724.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8876.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3256.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/2310.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9178.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8785.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7357.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4547.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5212.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3545.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7826.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6846.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/2236.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9640.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7224.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9710.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3027.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3490.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3456.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3179.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6163.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5292.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9016.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3442.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6445.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6453.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/2903.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4450.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6455.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7457.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4658.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4545.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4581.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9488.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5189.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3882.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9349.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/1080.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7819.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5697.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/1024.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7444.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9561.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5571.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3322.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6834.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8505.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5699.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8490.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4167.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3495.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6672.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8539.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/2450.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8679.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7645.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9087.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8642.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5914.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4912.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9849.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5721.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6905.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7293.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9769.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3333.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7600.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3837.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8361.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8157.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4184.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4917.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/1172.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4082.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/1644.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/1265.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4215.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9642.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4065.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/7319.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6029.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4851.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3004.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/2764.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/6047.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/5393.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/1477.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3170.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4763.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/1676.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4600.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9632.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8272.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3679.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3336.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/3468.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/4222.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/1710.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/9843.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/2383.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Image_dataset/A_val_img/8613.png
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Text_dataset/A_test.csv
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Text_dataset/A_train.csv
# /kaggle/input/meme-dataset/meme_dataset/meme_dataset/Text_dataset/A_val.csv

# %%
# Section 1: Install and Import Libraries
# !pip install --upgrade datasets transformers
# !pip install nltk emoji

import numpy as np
import pandas as pd
import torch
import random
import os
import json
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    Trainer,
    TrainingArguments,
    pipeline
)
from datasets import load_dataset, Dataset
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
import warnings
import zipfile
import re
import emoji
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
warnings.filterwarnings("ignore")
print("Libraries imported successfully!")

# Section 2: Set Random Seed for Reproducibility
def set_seed(seed_value):
    random.seed(seed_value)
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)
    torch.cuda.manual_seed_all(seed_value)
    os.environ['PYTHONHASHSEED'] = str(seed_value)

seed = 123
set_seed(seed)
print(f"Random seed set to {seed} for reproducibility.")

# Section 3: Importing the Datasets
df_train = pd.read_csv('/kaggle/input/meme-dataset/meme_dataset/meme_dataset/Text_dataset/A_train.csv')
df_val = pd.read_csv('/kaggle/input/meme-dataset/meme_dataset/meme_dataset/Text_dataset/A_val.csv')
df_test = pd.read_csv('/kaggle/input/meme-dataset/meme_dataset/meme_dataset/Text_dataset/A_test.csv')

print("Training Dataset:")
print(df_train.head())
print("\nVal Dataset:")
print(df_val.head())
print("\nTest Dataset:")
print(df_test.head())

# Section 4: Checking the Hate and Non-Hate Ratio
class_counts = df_train['label'].value_counts()
print("Class distribution in the training set:")
print(f"No Hate (0): {class_counts.get(0, 0)} samples")
print(f"Hate (1): {class_counts.get(1, 0)} samples")
print(f"Percentage No Hate (0): {(class_counts.get(0, 0) / len(df_train)) * 100:.2f}%")
print(f"Percentage Hate (1): {(class_counts.get(1, 0) / len(df_train)) * 100:.2f}%")

# Section 5: Text Cleaning (No Stopwords Removal, Less Aggressive)
def clean_text(text):
    text = text.lower()
    text = re.sub(r"n't", " not", text)
    text = re.sub(r"'re", " are", text)
    text = re.sub(r"'s", " is", text)
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'#\w+', '', text)
    text = emoji.replace_emoji(text, replace='')
    text = re.sub(r'(.)\\1{3,}', r'\\1\\1\\1', text)
    text = ''.join(c for c in text if c.isalnum() or c.isspace())
    text = re.sub(r'\s+', ' ', text).strip()
    return text

df_train['text'] = df_train['text'].apply(clean_text)
df_val['text'] = df_val['text'].apply(clean_text)
df_test['text'] = df_test['text'].apply(clean_text)

print("\nTraining dataset after cleaning:")
print(df_train.head())
print("\nVal dataset after cleaning:")
print(df_val.head())
print("\nTest dataset after cleaning:")
print(df_test.head())

# Section 6: Tokenization and Fine-Tuning with DistilBERT
def initialize_model(model_name):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)
    model.config.hidden_dropout_prob = 0.2
    model.config.attention_probs_dropout_prob = 0.2
    return tokenizer, model

selected_model = 'distilbert-base-uncased'
tokenizer, model = initialize_model(selected_model)

def tokenize_function(examples):
    return tokenizer(examples['text'], padding="max_length", truncation=True, max_length=128)

train_data, val_data = train_test_split(df_train, test_size=0.2, stratify=df_train['label'], random_state=seed)
dataset_train = Dataset.from_pandas(train_data[['text', 'label']])
dataset_val_internal = Dataset.from_pandas(val_data[['text', 'label']])
tokenized_train = dataset_train.map(tokenize_function, batched=True)
tokenized_val_internal = dataset_val_internal.map(tokenize_function, batched=True)
tokenized_train.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])
tokenized_val_internal.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])

dataset_test = Dataset.from_pandas(df_test[['text']])
tokenized_test = dataset_test.map(tokenize_function, batched=True)
tokenized_test.set_format('torch', columns=['input_ids', 'attention_mask'])

# Section 7: Train the Model
def compute_metrics(pred):
    labels = pred.label_ids
    preds = np.argmax(pred.predictions, axis=1)
    return {
        'accuracy': accuracy_score(labels, preds),
        'f1': f1_score(labels, preds),
        'precision': precision_score(labels, preds),
        'recall': recall_score(labels, preds)
    }

batch_size = 16
total_steps = (len(dataset_train) // batch_size) * 10
warmup_steps = int(0.1 * total_steps)
print(f"Total steps: {total_steps}, Warmup steps: {warmup_steps}")

training_args = TrainingArguments(
    output_dir=f'./results/{selected_model}_seed{seed}',
    report_to="none",
    num_train_epochs=10,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    warmup_steps=warmup_steps,
    weight_decay=0.01,
    learning_rate=1e-5,
    logging_dir=f'./logs/seed{seed}',
    logging_steps=50,
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    fp16=True,
)

class CustomTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        labels = inputs.get("labels")
        outputs = model(**inputs)
        logits = outputs.get("logits")
        loss_fct = torch.nn.CrossEntropyLoss()
        loss = loss_fct(logits.view(-1, self.model.config.num_labels), labels.view(-1))
        return (loss, outputs) if return_outputs else loss

trainer = CustomTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_val_internal,
    compute_metrics=compute_metrics,
)

trainer.train()
eval_results = trainer.evaluate()
print(f"\nEvaluation Results on Internal Validation Set (Seed {seed}, Model: {selected_model}):")
print(eval_results)

# Section 8: Prediction and JSON Format Conversion
predictions = trainer.predict(tokenized_test)
pred_labels = np.argmax(predictions.predictions, axis=1)

test_predictions = [{"index": str(idx), "prediction": int(pred)} for idx, pred in zip(df_test['index'], pred_labels)]
print("\nTest Predictions (First 5):")
for pred in test_predictions[:5]:
    print(pred)

with open('submission.json', 'w') as f:
    for pred in test_predictions:
        f.write(f'{{"index": "{pred["index"]}", "prediction": {pred["prediction"]}}}\n')

print("\nTest predictions saved to 'submission.json'")

with zipfile.ZipFile('ref.zip', 'w', zipfile.ZIP_DEFLATED) as zipf:
    zipf.write('submission.json')

print("\nZip file 'ref.zip' created with submission.json")
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.6.0)
# Collecting datasets
#   Downloading datasets-4.0.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.4)
# Collecting transformers
#   Downloading transformers-4.53.3-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.33.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.13)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.1.5)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.6.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->datasets) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->datasets) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->datasets) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->datasets) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->datasets) (2024.2.0)
# Downloading datasets-4.0.0-py3-none-any.whl (494 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 31.8 MB/s eta 0:00:00
# Downloading transformers-4.53.3-py3-none-any.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 116.4 MB/s eta 0:00:0000:010:01
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 12.8 MB/s eta 0:00:00
# Installing collected packages: fsspec, transformers, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.5.1
#     Uninstalling fsspec-2025.5.1:
#       Successfully uninstalled fsspec-2025.5.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.52.4
#     Uninstalling transformers-4.52.4:
#       Successfully uninstalled transformers-4.52.4
#   Attempting uninstall: datasets
#     Found existing installation: datasets 3.6.0
#     Uninstalling datasets-3.6.0:
#       Successfully uninstalled datasets-3.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.8.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# Successfully installed datasets-4.0.0 fsspec-2025.3.0 transformers-4.53.3
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: emoji in /usr/local/lib/python3.11/dist-packages (2.14.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# 2025-07-23 16:06:18.544796: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753286778.714682      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753286778.764061      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Libraries imported successfully!
# Random seed set to 123 for reproducibility.
# Training Dataset:
#       index                                               text  label
# 0  1001.png  transgirls who grow boobs but keep their cock ...      0
# 1  1005.png  realistic and wholesome representation of tran...      0
# 2  1008.png  united lgbt united sponsored you can color you...      0
# 3  1009.png  neolib politician i'm going to fuck my cat and...      1
# 4  1010.png  dad i'm gay i love you no matter what i also s...      1
#
# Val Dataset:
#       index                                               text  label
# 0  1003.png  soon available on every women's bathroom say t...      0
# 1  1024.png  sides gay fries fries but they're g ya know 6 ...      0
# 2  1045.png  me doesn't want to talk about dating sex with ...      1
# 3  1046.png  ferb trans rights says aren't you a little you...      0
# 4  1080.png  bethesda tr ethesda tr modle east bethesda rus...      1
#
# Test Dataset:
#       index                                               text
# 0  1002.png  imagine only being able to date this meme was ...
# 1  1011.png  every company during pride month i said we gay...
# 2  1040.png  ns righ ai fect just d trans phobe ersion py i...
# 3  1055.png  gay marriage shouldn't exist it should just be...
# 4  1115.png  me my gender staying female for a few days my ...
# Class distribution in the training set:
# No Hate (0): 2065 samples
# Hate (1): 1985 samples
# Percentage No Hate (0): 50.99%
# Percentage Hate (1): 49.01%
#
# Training dataset after cleaning:
#       index                                               text  label
# 0  1001.png  transgirls who grow boobs but keep their cock ...      0
# 1  1005.png  realistic and wholesome representation of tran...      0
# 2  1008.png  united lgbt united sponsored you can color you...      0
# 3  1009.png  neolib politician im going to fuck my cat and ...      1
# 4  1010.png  dad im gay i love you no matter what i also su...      1
#
# Val dataset after cleaning:
#       index                                               text  label
# 0  1003.png  soon available on every women is bathroom say ...      0
# 1  1024.png  sides gay fries fries but they are g ya know 6...      0
# 2  1045.png  me does not want to talk about dating sex with...      1
# 3  1046.png  ferb trans rights says are not you a little yo...      0
# 4  1080.png  bethesda tr ethesda tr modle east bethesda rus...      1
#
# Test dataset after cleaning:
#       index                                               text
# 0  1002.png  imagine only being able to date this meme was ...
# 1  1011.png  every company during pride month i said we gay...
# 2  1040.png  ns righ ai fect just d trans phobe ersion py i...
# 3  1055.png  gay marriage should not exist it should just b...
# 4  1115.png  me my gender staying female for a few days my ...
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/3240 [00:00<?, ? examples/s]
# Map:   0%|          | 0/810 [00:00<?, ? examples/s]
# Map:   0%|          | 0/507 [00:00<?, ? examples/s]
# Total steps: 2020, Warmup steps: 202
#     <div>
#
#       <progress value='2030' max='2030' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2030/2030 03:55, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.662900</td>
#       <td>0.642939</td>
#       <td>0.648148</td>
#       <td>0.691224</td>
#       <td>0.606464</td>
#       <td>0.803526</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.561700</td>
#       <td>0.568315</td>
#       <td>0.701235</td>
#       <td>0.673854</td>
#       <td>0.724638</td>
#       <td>0.629723</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.490900</td>
#       <td>0.562385</td>
#       <td>0.714815</td>
#       <td>0.710163</td>
#       <td>0.707500</td>
#       <td>0.712846</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.375200</td>
#       <td>0.571751</td>
#       <td>0.744444</td>
#       <td>0.741573</td>
#       <td>0.735149</td>
#       <td>0.748111</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.320500</td>
#       <td>0.649728</td>
#       <td>0.735802</td>
#       <td>0.737101</td>
#       <td>0.719424</td>
#       <td>0.755668</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.222200</td>
#       <td>0.743447</td>
#       <td>0.720988</td>
#       <td>0.692098</td>
#       <td>0.753709</td>
#       <td>0.639798</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.204700</td>
#       <td>0.866572</td>
#       <td>0.717284</td>
#       <td>0.712673</td>
#       <td>0.710000</td>
#       <td>0.715365</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.110900</td>
#       <td>0.934047</td>
#       <td>0.712346</td>
#       <td>0.703185</td>
#       <td>0.711340</td>
#       <td>0.695214</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.129600</td>
#       <td>1.010333</td>
#       <td>0.711111</td>
#       <td>0.710396</td>
#       <td>0.698297</td>
#       <td>0.722922</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.100600</td>
#       <td>1.034312</td>
#       <td>0.706173</td>
#       <td>0.695652</td>
#       <td>0.706494</td>
#       <td>0.685139</td>
#     </tr>
#   </tbody>
# </table><p>
# Evaluation Results on Internal Validation Set (Seed 123, Model: distilbert-base-uncased):
# {'eval_loss': 0.562384843826294, 'eval_accuracy': 0.7148148148148148, 'eval_f1': 0.7101631116687579, 'eval_precision': 0.7075, 'eval_recall': 0.7128463476070529, 'eval_runtime': 1.4806, 'eval_samples_per_second': 547.093, 'eval_steps_per_second': 34.447, 'epoch': 10.0}
#
# Test Predictions (First 5):
# {'index': '1002.png', 'prediction': 1}
# {'index': '1011.png', 'prediction': 1}
# {'index': '1040.png', 'prediction': 0}
# {'index': '1055.png', 'prediction': 1}
# {'index': '1115.png', 'prediction': 0}
#
# Test predictions saved to 'submission.json'
#
# Zip file 'ref.zip' created with submission.json
